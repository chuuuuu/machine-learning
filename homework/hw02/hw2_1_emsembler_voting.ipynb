# %% [markdown]
# # **Homework 2-1 Phoneme Classification**

# %% [markdown]
# ## The DARPA TIMIT Acoustic-Phonetic Continuous Speech Corpus (TIMIT)
# The TIMIT corpus of reading speech has been designed to provide speech data for the acquisition of acoustic-phonetic knowledge and for the development and evaluation of automatic speech recognition systems.
#
# This homework is a multiclass classification task,
# we are going to train a deep neural network classifier to predict the phonemes for each frame from the speech corpus TIMIT.
#
# link: https://academictorrents.com/details/34e2b78745138186976cbc27939b1b34d18bd5b3

# %% [markdown]
# ## Initialize

# %%
# %reset -f

# %% [markdown]
# ## Download Data
# Download data from google drive, then unzip it.
#
# You should have `timit_11/train_11.npy`, `timit_11/train_label_11.npy`, and `timit_11/test_11.npy` after running this block.<br><br>
# `timit_11/`
# - `train_11.npy`: training data<br>
# - `train_label_11.npy`: training label<br>
# - `test_11.npy`:  testing data<br><br>
#
# **notes: if the google drive link is dead, you can download the data directly from Kaggle and upload it to the workspace**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Preparing Data
# Load the training and testing data from the `.npy` file (NumPy array).

# %%
from sklearn import preprocessing
import numpy as np
import gc

class DataManager():
    def getTrainData(self):
        print('Loading data ...')
        
        data_root='gdrive/MyDrive/Colab Notebooks/HW2/HW2-1/timit_11/'
        train = np.load(data_root + 'train_11.npy')
        train_label = np.load(data_root + 'train_label_11.npy')
        
        self.scaler = preprocessing.StandardScaler().fit(train)
        train_scaled = self.scaler.transform(train)

        train_label_int = train_label.astype(np.int)
        label_num = max(train_label_int) - min(train_label_int) + 1 
        loss_weights = [0] * label_num
        for label in train_label_int:
            loss_weights[label] += 1

        for i in range(label_num):
            loss_weights[i] = len(train_label_int) / loss_weights[i]

        loss_weights_sum = sum(loss_weights)
        for i in range(label_num):
            loss_weights[i] = loss_weights[i] / loss_weights_sum
            # loss_weights[i] = loss_weights[i] / loss_weights[i]

        del train_label_int, train
        gc.collect()

        print('Size of training data: {}'.format(train_scaled.shape))

        return train_scaled, train_label, loss_weights

    def getTestData(self):
        print('Loading data ...')

        data_root='gdrive/MyDrive/Colab Notebooks/HW2/HW2-1/timit_11/'
        test = np.load(data_root + 'test_11.npy')
        test_scaled = self.scaler.transform(test)

        del test
        gc.collect()

        print('Size of testing data: {}'.format(test_scaled.shape))

        return test_scaled

dataManager = DataManager()

# %% [markdown]
# ## Configuration

# %%
config = {
    'BATCH_SIZE': 1024,
    'INPUT_DIM': 429,
    'OUTPUT_DIM': 39,
    'NUM_EPOCH': 10,
    # 'LEARNING_RATE': 0.0001,
    'MODEL_PATH': './model.ckpt',
    'MOMENTUM': 0.01,
    'EARLY_STOP': 10,
    'DROPOUT_PROB': 0.5,
    'INPUT_DROPOUT_PROB': 0.2,
    'TEST_SIZE': 0.1,
    'WIGHT_DECAY': 0,
    'MODEL_NUM': 20,
    'RANDOM_STATE': 0,
}

# %% [markdown]
# ## Create Dataset

# %%
import torch
from torch.utils.data import Dataset

class TIMITDataset(Dataset):
    def __init__(self, X, y=None):
        self.data = torch.from_numpy(X).float()
        if y is not None:
            y = y.astype(np.int)
            self.label = torch.LongTensor(y)
        else:
            self.label = None

    def __getitem__(self, idx):
        if self.label is not None:
            return self.data[idx], self.label[idx]
        else:
            return self.data[idx]

    def __len__(self):
        return len(self.data)

# %% [markdown]
# Split the labeled data into a training set and a validation set, you can modify the variable `VAL_RATIO` to change the ratio of validation data.

# %%
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split

def getTrainDataLoader():
    # get data
    train, train_label, loss_weights = dataManager.getTrainData()

    # split data into training and validation
    TEST_SIZE = config['TEST_SIZE']
    RANDOM_STATE = config['RANDOM_STATE']
    
    train_x, val_x, train_y, val_y = train_test_split(train, train_label, test_size=TEST_SIZE, stratify=train_label, random_state=RANDOM_STATE)
    config['RANDOM_STATE'] = RANDOM_STATE + 1

    print('Size of training set: {}'.format(train_x.shape))
    print('Size of validation set: {}'.format(val_x.shape))
    
    # save memory
    del train, train_label
    gc.collect()

    # create data loader
    print('Creating data loader...')
    BATCH_SIZE = config['BATCH_SIZE']
    train_set = TIMITDataset(train_x, train_y)
    val_set = TIMITDataset(val_x, val_y)
    train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True) #only shuffle the training data
    val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)

    # save memory
    del train_x, train_y, val_x, val_y
    gc.collect()

    return train_set, val_set, train_loader, val_loader, loss_weights

# %% [markdown]
# ## Create Model

# %% [markdown]
# Define model architecture, you are encouraged to change and experiment with the model architecture.

# %%
import torch
import torch.nn as nn
from torchsummary import summary


class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()

        INPUT_DIM = config['INPUT_DIM']
        OUTPUT_DIM = config['OUTPUT_DIM']
        MOMENTUM = config['MOMENTUM']
        DROPOUT_PROB = config['DROPOUT_PROB']
        INPUT_DROPOUT_PROB = config['INPUT_DROPOUT_PROB']


        self.layer1 = nn.Linear(INPUT_DIM, 2048)
        self.bn1 = nn.BatchNorm1d(2048, momentum=MOMENTUM)
        self.layer2 = nn.Linear(2048, 1024)
        self.bn2 = nn.BatchNorm1d(1024, momentum=MOMENTUM)
        self.layer3 = nn.Linear(1024, 512)
        self.bn3 = nn.BatchNorm1d(512, momentum=MOMENTUM)
        self.layer4 = nn.Linear(512, 256)
        self.bn4 = nn.BatchNorm1d(256, momentum=MOMENTUM)
        self.out = nn.Linear(256, OUTPUT_DIM) 

        self.act_fn = nn.ReLU()
        self.dropout = nn.Dropout(p=DROPOUT_PROB)
        self.input_dropout = nn.Dropout(p=INPUT_DROPOUT_PROB)

    def forward(self, x):
        # x = self.bn0(x)
        # x = self.input_dropout(x)
        
        x = self.layer1(x)
        x = self.act_fn(x)
        x = self.bn1(x)
        # x = self.dropout(x)

        x = self.layer2(x)
        x = self.act_fn(x)
        x = self.bn2(x)
        # x = self.dropout(x)

        x = self.layer3(x)
        x = self.act_fn(x)
        x = self.bn3(x)
        # x = self.dropout(x)

        x = self.layer4(x)
        x = self.act_fn(x)
        x = self.bn4(x)
        # x = self.dropout(x)

        x = self.out(x)
        
        return x

    def summary(self):
        INPUT_DIM = config['INPUT_DIM']
        summary(self, (INPUT_DIM, ))

# %% [markdown]
# ## Training

# %%
#check device
def get_device():
  return 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# Fix random seeds for reproducibility.

# %%
# fix random seed
def same_seeds(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  
    np.random.seed(seed)  
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %%
from sklearn.metrics import confusion_matrix

class Trainer():
    def train(self):
        # fix random seed for reproducibility
        same_seeds(0)

        # get device 
        device = get_device()
        print(f'DEVICE: {device}')

        # training parameters
        NUM_EPOCH = config['NUM_EPOCH']               # number of training epoch
        # LEARNING_RATE = config['LEARNING_RATE']       # learning rate
        WIGHT_DECAY = config['WIGHT_DECAY']
        EARLY_STOP = config['EARLY_STOP']
        
        # the path where checkpoint saved
        MODEL_PATH = config['MODEL_PATH']

        # load train data
        train_set, val_set, train_loader, val_loader, loss_weights = getTrainDataLoader()

        # create model, define a loss function, and optimizer
        model = Classifier().to(device)
        loss_weights = torch.FloatTensor(loss_weights).to(device)
        criterion = nn.CrossEntropyLoss(weight = loss_weights)
        optimizer = torch.optim.Adam(model.parameters(), weight_decay=WIGHT_DECAY)#, lr=LEARNING_RATE)

        # start training
        best_val_loss = float('inf')
        best_val_acc = 0.0
        best_train_loss = float('inf')
        best_train_acc = 0.0
        early_stop_count = 0
        best_predict = []
        best_true = []
        for epoch in range(NUM_EPOCH):
            train_acc = 0.0
            train_loss = 0.0
            val_acc = 0.0
            val_loss = 0.0

            # training
            model.train() # set the model to training mode
            for i, data in enumerate(train_loader):
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                optimizer.zero_grad() 
                outputs = model(inputs) 
                batch_loss = criterion(outputs, labels)
                _, train_pred = torch.max(outputs, 1) # get the index of the class with the highest probability
                batch_loss.backward() 
                optimizer.step() 

                train_acc += (train_pred.cpu() == labels.cpu()).sum().item()
                train_loss += batch_loss.item()

            # validation
            if len(val_set) > 0:
                predict = []
                true = []
                model.eval() # set the model to evaluation mode
                with torch.no_grad():
                    for i, data in enumerate(val_loader):
                        inputs, labels = data
                        inputs, labels = inputs.to(device), labels.to(device)
                        outputs = model(inputs)
                        batch_loss = criterion(outputs, labels) 
                        _, val_pred = torch.max(outputs, 1) 
                    
                        val_acc += (val_pred.cpu() == labels.cpu()).sum().item() # get the index of the class with the highest probability
                        val_loss += batch_loss.item()

                        for label in labels.cpu().numpy():
                            true.append(label)

                        for y in val_pred.cpu().numpy():
                            predict.append(y)


                    print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                        epoch + 1, NUM_EPOCH, train_acc/len(train_set), train_loss/len(train_loader), val_acc/len(val_set), val_loss/len(val_loader)
                    ))

                    # if the model improves, save a checkpoint at this epoch
                    if best_val_acc < val_acc:
                        early_stop_count = 0

                        best_predict = predict
                        best_true = true

                        best_val_loss = val_loss
                        best_val_acc = val_acc
                        best_train_loss = train_loss
                        best_train_acc = train_acc
                        torch.save(model.state_dict(), MODEL_PATH)
                        print('saving model with acc {:.3f}'.format(best_val_acc/len(val_set)))

                    else:
                        early_stop_count += 1

                    if early_stop_count > EARLY_STOP:
                        break
            else:
                print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f}'.format(
                    epoch + 1, NUM_EPOCH, train_acc/len(train_set), train_loss/len(train_loader)
                ))

        # if not validating, save the last epoch
        cf_matrix = None
        if len(val_set) == 0:
            torch.save(model.state_dict(), MODEL_PATH)
            print('saving model at last epoch')

        else:
            cf_matrix = confusion_matrix(best_true, best_predict)

        # print model layers
        model.summary()

        return best_train_acc/len(train_set), best_val_acc/len(val_set), best_train_loss/len(train_loader), best_val_loss/len(val_loader), cf_matrix

    def pred_y_test(self):
        # create testing dataset
        BATCH_SIZE = config['BATCH_SIZE']
        MODEL_PATH = config['MODEL_PATH']
        test = dataManager.getTestData()
        test_set = TIMITDataset(test, None)
        test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

        # create model and load weights from checkpoint
        device = get_device()
        model = Classifier().to(device)
        model.load_state_dict(torch.load(MODEL_PATH))

        # Make prediction.
        print('Predicting...')
        predict = []
        model.eval() # set the model to evaluation mode
        with torch.no_grad():
            for i, data in enumerate(test_loader):
                inputs = data
                inputs = inputs.to(device)
                outputs = model(inputs)
                _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

                for y in test_pred.cpu().numpy():
                    predict.append(y)
        
        return predict

# %%
  class Emssembler():
    def __init__(self):
        MODEL_NUM = config['MODEL_NUM']
        self.trainers = []
        for i in range(MODEL_NUM):
            self.trainers.append(Trainer())

    def train(self):
        MODEL_NUM = config['MODEL_NUM']
        for trainer in self.trainers:
            best_train_acc, best_val_acc, best_train_loss, best_val_loss, cf_matrix = trainer.train()
            print(f'best_train_acc: {best_train_acc}')
            print(f'best_val_acc: {best_val_acc}')
            print(f'best_train_loss:{best_train_loss}')
            print(f'best_val_loss:{best_val_loss}')
            for i in range(len(cf_matrix)):
                print(f'class {i} acc: {cf_matrix[i][i] / cf_matrix[i].sum()}')
                
    def pred(self):
        MODEL_NUM = config['MODEL_NUM']
        # PRED_PATH = config['PRED_PATH']
        
        y_preds = None
        for trainer in self.trainers:
            y_pred = np.array(trainer.pred_y_test())
            y_pred = np.reshape(y_pred, (y_pred.shape[0], 1))
            if y_preds is None:
                y_preds = y_pred
            else:
                y_preds = np.concatenate((y_preds, y_pred), axis=1)

        emssemble_y_preds = []
        for i in range(len(y_preds)):
            y_pred = self.most_freq(y_preds[i])
            emssemble_y_preds.append(y_pred)

        print('Saving...')
        with open('prediction.csv', 'w') as f:
            f.write('Id,Class\n')
            for i, y in enumerate(emssemble_y_preds):
                f.write('{},{}\n'.format(i, y))

        print('Finishing...')

    def most_freq(self, arr):
        freq_map = {}
        ret = arr[0]
        for x in arr:
            if x not in freq_map:
                freq_map[x] = 0
            
            freq_map[x] += 1
            if freq_map[x] > freq_map[ret]:
                ret = x
        
        return ret

emssembler = Emssembler()

# %%
emssembler.train()
emssembler.pred()
print(f'config: {config}')
# Out:
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.586123 Loss: 1.160072 | Val Acc: 0.637641 loss: 0.956201
# saving model with acc 0.638
# [002/010] Train Acc: 0.665341 Loss: 0.838203 | Val Acc: 0.666691 loss: 0.828505
# saving model with acc 0.667
# [003/010] Train Acc: 0.703599 Loss: 0.688720 | Val Acc: 0.704116 loss: 0.738927
# saving model with acc 0.704
# [004/010] Train Acc: 0.734219 Loss: 0.574244 | Val Acc: 0.718068 loss: 0.656695
# saving model with acc 0.718
# [005/010] Train Acc: 0.760769 Loss: 0.483911 | Val Acc: 0.740565 loss: 0.619736
# saving model with acc 0.741
# [006/010] Train Acc: 0.783518 Loss: 0.413155 | Val Acc: 0.753329 loss: 0.588382
# saving model with acc 0.753
# [007/010] Train Acc: 0.803851 Loss: 0.356681 | Val Acc: 0.758574 loss: 0.584057
# saving model with acc 0.759
# [008/010] Train Acc: 0.820950 Loss: 0.314775 | Val Acc: 0.774965 loss: 0.557618
# saving model with acc 0.775
# [009/010] Train Acc: 0.836312 Loss: 0.277117 | Val Acc: 0.775623 loss: 0.560530
# saving model with acc 0.776
# [010/010] Train Acc: 0.849062 Loss: 0.247533 | Val Acc: 0.790063 loss: 0.558762
# saving model with acc 0.790
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8490620070862144
# best_val_acc: 0.7900629298990195
# best_train_loss:0.24753263632695394
# best_val_loss:0.5587622451880747
# class 0 acc: 0.8233136660819645
# class 1 acc: 0.585910447761194
# class 2 acc: 0.7144079885877318
# class 3 acc: 0.8119600203286464
# class 4 acc: 0.697148728487028
# class 5 acc: 0.8669446550416983
# class 6 acc: 0.849009900990099
# class 7 acc: 0.7758363808749831
# class 8 acc: 0.8381944444444445
# class 9 acc: 0.9020122484689413
# class 10 acc: 0.9456029011786038
# class 11 acc: 0.9180187873612298
# class 12 acc: 0.8525569242254573
# class 13 acc: 0.7910619672886432
# class 14 acc: 0.7963617988883275
# class 15 acc: 0.8765432098765432
# class 16 acc: 0.885755258126195
# class 17 acc: 0.8400931496215797
# class 18 acc: 0.8648757016840417
# class 19 acc: 0.8261793455163621
# class 20 acc: 0.8977673325499412
# class 21 acc: 0.8502824858757062
# class 22 acc: 0.9290780141843972
# class 23 acc: 0.7607879924953096
# class 24 acc: 0.845360824742268
# class 25 acc: 0.7688564476885644
# class 26 acc: 0.8671775223499362
# class 27 acc: 0.8531353135313532
# class 28 acc: 0.8581375108790252
# class 29 acc: 0.8529271775345074
# class 30 acc: 0.9059760956175299
# class 31 acc: 0.8244781783681214
# class 32 acc: 0.8225
# class 33 acc: 0.8821475338280227
# class 34 acc: 0.8815028901734104
# class 35 acc: 0.8183861807856129
# class 36 acc: 0.9206349206349206
# class 37 acc: 0.8453389830508474
# class 38 acc: 0.6795926361143753
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.587814 Loss: 1.156180 | Val Acc: 0.635299 loss: 0.951851
# saving model with acc 0.635
# [002/010] Train Acc: 0.665942 Loss: 0.837694 | Val Acc: 0.669667 loss: 0.810837
# saving model with acc 0.670
# [003/010] Train Acc: 0.703196 Loss: 0.689511 | Val Acc: 0.697709 loss: 0.735598
# saving model with acc 0.698
# [004/010] Train Acc: 0.733908 Loss: 0.575656 | Val Acc: 0.723060 loss: 0.676142
# saving model with acc 0.723
# [005/010] Train Acc: 0.760233 Loss: 0.484814 | Val Acc: 0.735109 loss: 0.634039
# saving model with acc 0.735
# [006/010] Train Acc: 0.784295 Loss: 0.410267 | Val Acc: 0.748541 loss: 0.606362
# saving model with acc 0.749
# [007/010] Train Acc: 0.803678 Loss: 0.356915 | Val Acc: 0.757143 loss: 0.583160
# saving model with acc 0.757
# [008/010] Train Acc: 0.820798 Loss: 0.314246 | Val Acc: 0.771802 loss: 0.579805
# saving model with acc 0.772
# [009/010] Train Acc: 0.834993 Loss: 0.280682 | Val Acc: 0.776404 loss: 0.560061
# saving model with acc 0.776
# [010/010] Train Acc: 0.849810 Loss: 0.246500 | Val Acc: 0.780721 loss: 0.575706
# saving model with acc 0.781
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8498100164598198
# best_val_acc: 0.7807210107810137
# best_train_loss:0.24650023395159418
# best_val_loss:0.5757055260425756
# class 0 acc: 0.7616010205708819
# class 1 acc: 0.5935522388059702
# class 2 acc: 0.7922967189728959
# class 3 acc: 0.8031509401998984
# class 4 acc: 0.7066529668636014
# class 5 acc: 0.8578468536770281
# class 6 acc: 0.8564356435643564
# class 7 acc: 0.7794934308546662
# class 8 acc: 0.8482638888888889
# class 9 acc: 0.8745990084572762
# class 10 acc: 0.9229374433363554
# class 11 acc: 0.9248505550811272
# class 12 acc: 0.8230683090705487
# class 13 acc: 0.797281732319742
# class 14 acc: 0.8019201616978272
# class 15 acc: 0.8791887125220459
# class 16 acc: 0.8943594646271511
# class 17 acc: 0.8263147680962546
# class 18 acc: 0.859663191659984
# class 19 acc: 0.7620059498512537
# class 20 acc: 0.8907168037602821
# class 21 acc: 0.8629943502824858
# class 22 acc: 0.8652482269503546
# class 23 acc: 0.8039399624765479
# class 24 acc: 0.8402061855670103
# class 25 acc: 0.7396593673965937
# class 26 acc: 0.8825031928480205
# class 27 acc: 0.858085808580858
# class 28 acc: 0.8920800696257616
# class 29 acc: 0.7710613993336506
# class 30 acc: 0.9119521912350598
# class 31 acc: 0.8279569892473119
# class 32 acc: 0.8266666666666667
# class 33 acc: 0.8982976865997381
# class 34 acc: 0.7557803468208093
# class 35 acc: 0.8379081874112636
# class 36 acc: 0.9095607235142119
# class 37 acc: 0.8629943502824858
# class 38 acc: 0.6452352974092105
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.586454 Loss: 1.156996 | Val Acc: 0.646926 loss: 0.955924
# saving model with acc 0.647
# [002/010] Train Acc: 0.664758 Loss: 0.840674 | Val Acc: 0.676000 loss: 0.830028
# saving model with acc 0.676
# [003/010] Train Acc: 0.702087 Loss: 0.691350 | Val Acc: 0.704685 loss: 0.746575
# saving model with acc 0.705
# [004/010] Train Acc: 0.732509 Loss: 0.578981 | Val Acc: 0.716230 loss: 0.663296
# saving model with acc 0.716
# [005/010] Train Acc: 0.759755 Loss: 0.486647 | Val Acc: 0.742052 loss: 0.621626
# saving model with acc 0.742
# [006/010] Train Acc: 0.783693 Loss: 0.412286 | Val Acc: 0.745175 loss: 0.604496
# saving model with acc 0.745
# [007/010] Train Acc: 0.802507 Loss: 0.358730 | Val Acc: 0.759135 loss: 0.583418
# saving model with acc 0.759
# [008/010] Train Acc: 0.821280 Loss: 0.311900 | Val Acc: 0.770233 loss: 0.565621
# saving model with acc 0.770
# [009/010] Train Acc: 0.836375 Loss: 0.276911 | Val Acc: 0.776257 loss: 0.568012
# saving model with acc 0.776
# [010/010] Train Acc: 0.848276 Loss: 0.250623 | Val Acc: 0.787055 loss: 0.548670
# saving model with acc 0.787
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8482760552081507
# best_val_acc: 0.7870546530725075
# best_train_loss:0.25062254850066007
# best_val_loss:0.5486696062009196
# class 0 acc: 0.7769095837984372
# class 1 acc: 0.5922388059701492
# class 2 acc: 0.7195435092724679
# class 3 acc: 0.8189056411993901
# class 4 acc: 0.6984330850244028
# class 5 acc: 0.8692191053828658
# class 6 acc: 0.8193069306930693
# class 7 acc: 0.7923608289313288
# class 8 acc: 0.8527777777777777
# class 9 acc: 0.8731408573928259
# class 10 acc: 0.9483227561196736
# class 11 acc: 0.92399658411614
# class 12 acc: 0.8521836506159015
# class 13 acc: 0.7823082239115411
# class 14 acc: 0.8137948458817584
# class 15 acc: 0.8818342151675485
# class 16 acc: 0.9024856596558317
# class 17 acc: 0.8156413739569183
# class 18 acc: 0.863672814755413
# class 19 acc: 0.7887802804929877
# class 20 acc: 0.9048178613396005
# class 21 acc: 0.922316384180791
# class 22 acc: 0.900709219858156
# class 23 acc: 0.8123827392120075
# class 24 acc: 0.8247422680412371
# class 25 acc: 0.8004866180048662
# class 26 acc: 0.8518518518518519
# class 27 acc: 0.8927392739273927
# class 28 acc: 0.8877284595300261
# class 29 acc: 0.8039029033793431
# class 30 acc: 0.8924302788844621
# class 31 acc: 0.7944339025932954
# class 32 acc: 0.81
# class 33 acc: 0.8651243998254038
# class 34 acc: 0.8713872832369942
# class 35 acc: 0.8547089446284903
# class 36 acc: 0.9176818014027316
# class 37 acc: 0.8792372881355932
# class 38 acc: 0.6661071008897096
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.587474 Loss: 1.155139 | Val Acc: 0.636470 loss: 0.960773
# saving model with acc 0.636
# [002/010] Train Acc: 0.665445 Loss: 0.838258 | Val Acc: 0.667049 loss: 0.825929
# saving model with acc 0.667
# [003/010] Train Acc: 0.703334 Loss: 0.688871 | Val Acc: 0.689773 loss: 0.743185
# saving model with acc 0.690
# [004/010] Train Acc: 0.733963 Loss: 0.575197 | Val Acc: 0.726279 loss: 0.672113
# saving model with acc 0.726
# [005/010] Train Acc: 0.760214 Loss: 0.483825 | Val Acc: 0.732597 loss: 0.628824
# saving model with acc 0.733
# [006/010] Train Acc: 0.783655 Loss: 0.413679 | Val Acc: 0.751110 loss: 0.601113
# saving model with acc 0.751
# [007/010] Train Acc: 0.804139 Loss: 0.357048 | Val Acc: 0.758883 loss: 0.591109
# saving model with acc 0.759
# [008/010] Train Acc: 0.820611 Loss: 0.313747 | Val Acc: 0.771883 loss: 0.574520
# saving model with acc 0.772
# [009/010] Train Acc: 0.834867 Loss: 0.278894 | Val Acc: 0.782477 loss: 0.558434
# saving model with acc 0.782
# [010/010] Train Acc: 0.849311 Loss: 0.247953 | Val Acc: 0.790193 loss: 0.557976
# saving model with acc 0.790
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8493113435440829
# best_val_acc: 0.7901930175455714
# best_train_loss:0.24795273198616052
# best_val_loss:0.5579763081940737
# class 0 acc: 0.8362302663052145
# class 1 acc: 0.5620298507462687
# class 2 acc: 0.7420827389443652
# class 3 acc: 0.8426223953921734
# class 4 acc: 0.6475725661443616
# class 5 acc: 0.8483699772554966
# class 6 acc: 0.7821782178217822
# class 7 acc: 0.7904645807937153
# class 8 acc: 0.8802083333333334
# class 9 acc: 0.8751822688830563
# class 10 acc: 0.9256572982774252
# class 11 acc: 0.8941076003415884
# class 12 acc: 0.8376259798432251
# class 13 acc: 0.8364432158488827
# class 14 acc: 0.8362809499747347
# class 15 acc: 0.8809523809523809
# class 16 acc: 0.8972275334608031
# class 17 acc: 0.8144770036871726
# class 18 acc: 0.8492381716118684
# class 19 acc: 0.7849553761155971
# class 20 acc: 0.9165687426556992
# class 21 acc: 0.8488700564971752
# class 22 acc: 0.8921985815602836
# class 23 acc: 0.7823639774859287
# class 24 acc: 0.8891752577319587
# class 25 acc: 0.7396593673965937
# class 26 acc: 0.9016602809706258
# class 27 acc: 0.8646864686468647
# class 28 acc: 0.8694516971279374
# class 29 acc: 0.843407900999524
# class 30 acc: 0.904780876494024
# class 31 acc: 0.838393421884883
# class 32 acc: 0.8125
# class 33 acc: 0.853339153208206
# class 34 acc: 0.8713872832369942
# class 35 acc: 0.8085660198769522
# class 36 acc: 0.9187892211148025
# class 37 acc: 0.8608757062146892
# class 38 acc: 0.687314643836383
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.586451 Loss: 1.156741 | Val Acc: 0.633689 loss: 0.965401
# saving model with acc 0.634
# [002/010] Train Acc: 0.665989 Loss: 0.838785 | Val Acc: 0.673618 loss: 0.812945
# saving model with acc 0.674
# [003/010] Train Acc: 0.703459 Loss: 0.689201 | Val Acc: 0.688042 loss: 0.729878
# saving model with acc 0.688
# [004/010] Train Acc: 0.733812 Loss: 0.574721 | Val Acc: 0.720669 loss: 0.670889
# saving model with acc 0.721
# [005/010] Train Acc: 0.760575 Loss: 0.485003 | Val Acc: 0.733426 loss: 0.639938
# saving model with acc 0.733
# [006/010] Train Acc: 0.784469 Loss: 0.413038 | Val Acc: 0.739882 loss: 0.608650
# saving model with acc 0.740
# [007/010] Train Acc: 0.803953 Loss: 0.357621 | Val Acc: 0.757793 loss: 0.591112
# saving model with acc 0.758
# [008/010] Train Acc: 0.822213 Loss: 0.312001 | Val Acc: 0.767509 loss: 0.579621
# saving model with acc 0.768
# [009/010] Train Acc: 0.836189 Loss: 0.278271 | Val Acc: 0.778526 loss: 0.573535
# saving model with acc 0.779
# [010/010] Train Acc: 0.849497 Loss: 0.247327 | Val Acc: 0.785258 loss: 0.568558
# saving model with acc 0.785
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.849497442494521
# best_val_acc: 0.78525781745451
# best_train_loss:0.24732719977954049
# best_val_loss:0.5685576764512653
# class 0 acc: 0.8153404560676129
# class 1 acc: 0.5988059701492537
# class 2 acc: 0.6807417974322396
# class 3 acc: 0.8546501778756564
# class 4 acc: 0.7002311841767275
# class 5 acc: 0.854814253222138
# class 6 acc: 0.8118811881188119
# class 7 acc: 0.7771908438304213
# class 8 acc: 0.8243055555555555
# class 9 acc: 0.8929717118693496
# class 10 acc: 0.9356300997280145
# class 11 acc: 0.9077711357813835
# class 12 acc: 0.8540500186636805
# class 13 acc: 0.7933655839668279
# class 14 acc: 0.8021728145528044
# class 15 acc: 0.8880070546737213
# class 16 acc: 0.8652007648183556
# class 17 acc: 0.8268969532311276
# class 18 acc: 0.8416198877305533
# class 19 acc: 0.8100297492562686
# class 20 acc: 0.8860164512338425
# class 21 acc: 0.8305084745762712
# class 22 acc: 0.8468085106382979
# class 23 acc: 0.8076923076923077
# class 24 acc: 0.8324742268041238
# class 25 acc: 0.7615571776155717
# class 26 acc: 0.8876117496807152
# class 27 acc: 0.8432343234323433
# class 28 acc: 0.855526544821584
# class 29 acc: 0.8638743455497382
# class 30 acc: 0.8828685258964143
# class 31 acc: 0.8636938646426312
# class 32 acc: 0.8066666666666666
# class 33 acc: 0.8725447402880838
# class 34 acc: 0.8453757225433526
# class 35 acc: 0.794368196876479
# class 36 acc: 0.9346622369878184
# class 37 acc: 0.8806497175141242
# class 38 acc: 0.6605114431201388
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.587676 Loss: 1.156357 | Val Acc: 0.649032 loss: 0.969727
# saving model with acc 0.649
# [002/010] Train Acc: 0.665739 Loss: 0.839136 | Val Acc: 0.673586 loss: 0.834317
# saving model with acc 0.674
# [003/010] Train Acc: 0.703546 Loss: 0.690322 | Val Acc: 0.695473 loss: 0.746691
# saving model with acc 0.695
# [004/010] Train Acc: 0.733985 Loss: 0.575057 | Val Acc: 0.720303 loss: 0.678805
# saving model with acc 0.720
# [005/010] Train Acc: 0.760692 Loss: 0.485475 | Val Acc: 0.734198 loss: 0.631420
# saving model with acc 0.734
# [006/010] Train Acc: 0.784069 Loss: 0.412479 | Val Acc: 0.749980 loss: 0.608674
# saving model with acc 0.750
# [007/010] Train Acc: 0.804162 Loss: 0.358033 | Val Acc: 0.758069 loss: 0.583138
# saving model with acc 0.758
# [008/010] Train Acc: 0.821164 Loss: 0.314610 | Val Acc: 0.770428 loss: 0.553622
# saving model with acc 0.770
# [009/010] Train Acc: 0.836906 Loss: 0.275663 | Val Acc: 0.780501 loss: 0.561871
# saving model with acc 0.781
# [010/010] Train Acc: 0.849076 Loss: 0.249115 | Val Acc: 0.785461 loss: 0.559367
# saving model with acc 0.785
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.849076461373627
# best_val_acc: 0.7854610794022473
# best_train_loss:0.24911469244548945
# best_val_loss:0.5593665424457266
# class 0 acc: 0.7823313666081965
# class 1 acc: 0.5707462686567164
# class 2 acc: 0.771469329529244
# class 3 acc: 0.8253430459088599
# class 4 acc: 0.6778833804264064
# class 5 acc: 0.8453373768006065
# class 6 acc: 0.8143564356435643
# class 7 acc: 0.8301503453880537
# class 8 acc: 0.8527777777777777
# class 9 acc: 0.8346456692913385
# class 10 acc: 0.9193109700815957
# class 11 acc: 0.8949615713065756
# class 12 acc: 0.8551698394923479
# class 13 acc: 0.8184750057590416
# class 14 acc: 0.8115209701869631
# class 15 acc: 0.8994708994708994
# class 16 acc: 0.8847992351816444
# class 17 acc: 0.8336891131379779
# class 18 acc: 0.8516439454691259
# class 19 acc: 0.7855928601784955
# class 20 acc: 0.927144535840188
# class 21 acc: 0.864406779661017
# class 22 acc: 0.8780141843971632
# class 23 acc: 0.8142589118198874
# class 24 acc: 0.8015463917525774
# class 25 acc: 0.8503649635036497
# class 26 acc: 0.8620689655172413
# class 27 acc: 0.8745874587458746
# class 28 acc: 0.9112271540469974
# class 29 acc: 0.8257972394098049
# class 30 acc: 0.8816733067729083
# class 31 acc: 0.8425047438330171
# class 32 acc: 0.8233333333333334
# class 33 acc: 0.8856394587516369
# class 34 acc: 0.8367052023121387
# class 35 acc: 0.8173213440605773
# class 36 acc: 0.8970099667774086
# class 37 acc: 0.8742937853107344
# class 38 acc: 0.6524536959319568
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.587280 Loss: 1.155187 | Val Acc: 0.637007 loss: 0.965754
# saving model with acc 0.637
# [002/010] Train Acc: 0.666359 Loss: 0.837099 | Val Acc: 0.675903 loss: 0.831357
# saving model with acc 0.676
# [003/010] Train Acc: 0.703442 Loss: 0.688529 | Val Acc: 0.699595 loss: 0.736359
# saving model with acc 0.700
# [004/010] Train Acc: 0.734140 Loss: 0.574547 | Val Acc: 0.716547 loss: 0.670111
# saving model with acc 0.717
# [005/010] Train Acc: 0.760965 Loss: 0.482901 | Val Acc: 0.735028 loss: 0.615054
# saving model with acc 0.735
# [006/010] Train Acc: 0.784952 Loss: 0.409795 | Val Acc: 0.754021 loss: 0.601437
# saving model with acc 0.754
# [007/010] Train Acc: 0.804204 Loss: 0.356054 | Val Acc: 0.762980 loss: 0.585587
# saving model with acc 0.763
# [008/010] Train Acc: 0.820947 Loss: 0.313055 | Val Acc: 0.771851 loss: 0.566275
# saving model with acc 0.772
# [009/010] Train Acc: 0.836488 Loss: 0.274868 | Val Acc: 0.778192 loss: 0.573747
# saving model with acc 0.778
# [010/010] Train Acc: 0.848511 Loss: 0.250215 | Val Acc: 0.786957 loss: 0.566159
# saving model with acc 0.787
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8485109373786066
# best_val_acc: 0.7869570873375937
# best_train_loss:0.25021452813044837
# best_val_loss:0.5661587394958685
# class 0 acc: 0.8324031254983256
# class 1 acc: 0.5776716417910448
# class 2 acc: 0.7252496433666191
# class 3 acc: 0.8268676943926817
# class 4 acc: 0.6496275366041613
# class 5 acc: 0.8639120545868082
# class 6 acc: 0.8737623762376238
# class 7 acc: 0.7771908438304213
# class 8 acc: 0.8864583333333333
# class 9 acc: 0.8708078156897054
# class 10 acc: 0.9401631912964642
# class 11 acc: 0.9350982066609735
# class 12 acc: 0.8992161254199328
# class 13 acc: 0.770099055517162
# class 14 acc: 0.8390601313794845
# class 15 acc: 0.8941798941798942
# class 16 acc: 0.9005736137667304
# class 17 acc: 0.7958470793712401
# class 18 acc: 0.8572574178027266
# class 19 acc: 0.7928176795580111
# class 20 acc: 0.8766157461809636
# class 21 acc: 0.8799435028248588
# class 22 acc: 0.8765957446808511
# class 23 acc: 0.8386491557223265
# class 24 acc: 0.7190721649484536
# class 25 acc: 0.7968369829683698
# class 26 acc: 0.8492975734355045
# class 27 acc: 0.8960396039603961
# class 28 acc: 0.7998259355961705
# class 29 acc: 0.8315088053307949
# class 30 acc: 0.8872509960159363
# class 31 acc: 0.8406072106261859
# class 32 acc: 0.8233333333333334
# class 33 acc: 0.8786556089044085
# class 34 acc: 0.7644508670520231
# class 35 acc: 0.810459062943682
# class 36 acc: 0.9150978220745662
# class 37 acc: 0.8806497175141242
# class 38 acc: 0.6781377650942868
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.586735 Loss: 1.156352 | Val Acc: 0.628827 loss: 0.966185
# saving model with acc 0.629
# [002/010] Train Acc: 0.664937 Loss: 0.837778 | Val Acc: 0.683180 loss: 0.806794
# saving model with acc 0.683
# [003/010] Train Acc: 0.702860 Loss: 0.689748 | Val Acc: 0.699278 loss: 0.722357
# saving model with acc 0.699
# [004/010] Train Acc: 0.733560 Loss: 0.575703 | Val Acc: 0.718393 loss: 0.669288
# saving model with acc 0.718
# [005/010] Train Acc: 0.759493 Loss: 0.485755 | Val Acc: 0.735402 loss: 0.616572
# saving model with acc 0.735
# [006/010] Train Acc: 0.783315 Loss: 0.413312 | Val Acc: 0.750264 loss: 0.576490
# saving model with acc 0.750
# [007/010] Train Acc: 0.804550 Loss: 0.354557 | Val Acc: 0.762484 loss: 0.580148
# saving model with acc 0.762
# [008/010] Train Acc: 0.820752 Loss: 0.313444 | Val Acc: 0.769135 loss: 0.558989
# saving model with acc 0.769
# [009/010] Train Acc: 0.836240 Loss: 0.276534 | Val Acc: 0.781103 loss: 0.558651
# saving model with acc 0.781
# [010/010] Train Acc: 0.848299 Loss: 0.249751 | Val Acc: 0.785575 loss: 0.539964
# saving model with acc 0.786
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8482986400322331
# best_val_acc: 0.7855749060929802
# best_train_loss:0.24975149995138202
# best_val_loss:0.5399641623674345
# class 0 acc: 0.8111943868601499
# class 1 acc: 0.601313432835821
# class 2 acc: 0.7592011412268188
# class 3 acc: 0.8026427240386245
# class 4 acc: 0.7058823529411765
# class 5 acc: 0.8544351781652767
# class 6 acc: 0.8391089108910891
# class 7 acc: 0.7790870919680347
# class 8 acc: 0.8552083333333333
# class 9 acc: 0.8565179352580927
# class 10 acc: 0.9374433363553943
# class 11 acc: 0.9035012809564474
# class 12 acc: 0.8768197088465846
# class 13 acc: 0.7401520387007602
# class 14 acc: 0.8418393127842345
# class 15 acc: 0.9215167548500882
# class 16 acc: 0.9144359464627151
# class 17 acc: 0.8210751018823986
# class 18 acc: 0.8957497995188453
# class 19 acc: 0.7909052273693158
# class 20 acc: 0.8390129259694477
# class 21 acc: 0.9265536723163842
# class 22 acc: 0.8524822695035461
# class 23 acc: 0.8367729831144465
# class 24 acc: 0.8505154639175257
# class 25 acc: 0.8126520681265207
# class 26 acc: 0.8748403575989783
# class 27 acc: 0.8778877887788779
# class 28 acc: 0.917319408181027
# class 29 acc: 0.8391242265587815
# class 30 acc: 0.897609561752988
# class 31 acc: 0.8500948766603416
# class 32 acc: 0.8225
# class 33 acc: 0.8559580969009166
# class 34 acc: 0.846820809248555
# class 35 acc: 0.7872692853762423
# class 36 acc: 0.9184200812107789
# class 37 acc: 0.844632768361582
# class 38 acc: 0.6584410497453975
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.586982 Loss: 1.155798 | Val Acc: 0.639560 loss: 0.946888
# saving model with acc 0.640
# [002/010] Train Acc: 0.665891 Loss: 0.838338 | Val Acc: 0.673358 loss: 0.810958
# saving model with acc 0.673
# [003/010] Train Acc: 0.703130 Loss: 0.689767 | Val Acc: 0.706766 loss: 0.730439
# saving model with acc 0.707
# [004/010] Train Acc: 0.733771 Loss: 0.575400 | Val Acc: 0.722954 loss: 0.669781
# saving model with acc 0.723
# [005/010] Train Acc: 0.760682 Loss: 0.485587 | Val Acc: 0.728393 loss: 0.637364
# saving model with acc 0.728
# [006/010] Train Acc: 0.783468 Loss: 0.412962 | Val Acc: 0.757630 loss: 0.610962
# saving model with acc 0.758
# [007/010] Train Acc: 0.803455 Loss: 0.357642 | Val Acc: 0.758216 loss: 0.574346
# saving model with acc 0.758
# [008/010] Train Acc: 0.821535 Loss: 0.312092 | Val Acc: 0.772566 loss: 0.561279
# saving model with acc 0.773
# [009/010] Train Acc: 0.836279 Loss: 0.277237 | Val Acc: 0.786843 loss: 0.572446
# saving model with acc 0.787
# [010/010] Train Acc: 0.848830 Loss: 0.249088 | Val Acc: 0.786575 loss: 0.558699
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8362789966556392
# best_val_acc: 0.7868432606468608
# best_train_loss:0.2772372580175594
# best_val_loss:0.5724459105779317
# class 0 acc: 0.8261840216871312
# class 1 acc: 0.5867462686567164
# class 2 acc: 0.76490727532097
# class 3 acc: 0.8194138573606641
# class 4 acc: 0.6609298741330594
# class 5 acc: 0.8582259287338894
# class 6 acc: 0.8217821782178217
# class 7 acc: 0.7931735067045916
# class 8 acc: 0.8645833333333334
# class 9 acc: 0.8349372995042287
# class 10 acc: 0.9383499546690843
# class 11 acc: 0.9060631938514091
# class 12 acc: 0.8678611422172452
# class 13 acc: 0.78852798894264
# class 14 acc: 0.7812026275896917
# class 15 acc: 0.8756613756613757
# class 16 acc: 0.8695028680688337
# class 17 acc: 0.8464971861051814
# class 18 acc: 0.8736968724939855
# class 19 acc: 0.7821929451763706
# class 20 acc: 0.8860164512338425
# class 21 acc: 0.8983050847457628
# class 22 acc: 0.8326241134751773
# class 23 acc: 0.8386491557223265
# class 24 acc: 0.7551546391752577
# class 25 acc: 0.7372262773722628
# class 26 acc: 0.879948914431673
# class 27 acc: 0.8828382838283828
# class 28 acc: 0.8511749347258486
# class 29 acc: 0.8419800095192765
# class 30 acc: 0.8820717131474104
# class 31 acc: 0.782416192283365
# class 32 acc: 0.8275
# class 33 acc: 0.8865124399825404
# class 34 acc: 0.819364161849711
# class 35 acc: 0.837789872219593
# class 36 acc: 0.9272794389073459
# class 37 acc: 0.867231638418079
# class 38 acc: 0.6700800179061048
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.587093 Loss: 1.157585 | Val Acc: 0.638031 loss: 0.947661
# saving model with acc 0.638
# [002/010] Train Acc: 0.664853 Loss: 0.840171 | Val Acc: 0.667122 loss: 0.823628
# saving model with acc 0.667
# [003/010] Train Acc: 0.702898 Loss: 0.691588 | Val Acc: 0.699302 loss: 0.729539
# saving model with acc 0.699
# [004/010] Train Acc: 0.733565 Loss: 0.576243 | Val Acc: 0.725409 loss: 0.666559
# saving model with acc 0.725
# [005/010] Train Acc: 0.759286 Loss: 0.487642 | Val Acc: 0.736166 loss: 0.629074
# saving model with acc 0.736
# [006/010] Train Acc: 0.782606 Loss: 0.414990 | Val Acc: 0.751313 loss: 0.605318
# saving model with acc 0.751
# [007/010] Train Acc: 0.803761 Loss: 0.356949 | Val Acc: 0.760273 loss: 0.582785
# saving model with acc 0.760
# [008/010] Train Acc: 0.820850 Loss: 0.314401 | Val Acc: 0.768501 loss: 0.568702
# saving model with acc 0.769
# [009/010] Train Acc: 0.835220 Loss: 0.278493 | Val Acc: 0.780249 loss: 0.562045
# saving model with acc 0.780
# [010/010] Train Acc: 0.848438 Loss: 0.249825 | Val Acc: 0.790624 loss: 0.558157
# saving model with acc 0.791
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8484377625485799
# best_val_acc: 0.7906239328747744
# best_train_loss:0.2498249333562066
# best_val_loss:0.5581568639633084
# class 0 acc: 0.793493860628289
# class 1 acc: 0.5732537313432836
# class 2 acc: 0.7748930099857346
# class 3 acc: 0.8189056411993901
# class 4 acc: 0.6850757770357051
# class 5 acc: 0.8714935557240333
# class 6 acc: 0.8292079207920792
# class 7 acc: 0.7828795882432615
# class 8 acc: 0.8875
# class 9 acc: 0.8696412948381452
# class 10 acc: 0.9501359927470535
# class 11 acc: 0.8821520068317678
# class 12 acc: 0.8701007838745801
# class 13 acc: 0.782768947247178
# class 14 acc: 0.7885295603840323
# class 15 acc: 0.8880070546737213
# class 16 acc: 0.8867112810707457
# class 17 acc: 0.8261207063846303
# class 18 acc: 0.8608660785886126
# class 19 acc: 0.8210794730131746
# class 20 acc: 0.9036427732079906
# class 21 acc: 0.8870056497175142
# class 22 acc: 0.8638297872340426
# class 23 acc: 0.801125703564728
# class 24 acc: 0.7989690721649485
# class 25 acc: 0.7883211678832117
# class 26 acc: 0.8722860791826309
# class 27 acc: 0.8564356435643564
# class 28 acc: 0.9155787641427328
# class 29 acc: 0.8300809138505474
# class 30 acc: 0.8852589641434263
# class 31 acc: 0.8323845667299178
# class 32 acc: 0.8125
# class 33 acc: 0.8847664775207333
# class 34 acc: 0.8121387283236994
# class 35 acc: 0.819569332702319
# class 36 acc: 0.9210040605389442
# class 37 acc: 0.855225988700565
# class 38 acc: 0.6920709529405181
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.587472 Loss: 1.155082 | Val Acc: 0.635812 loss: 0.960615
# saving model with acc 0.636
# [002/010] Train Acc: 0.665370 Loss: 0.839153 | Val Acc: 0.673431 loss: 0.832701
# saving model with acc 0.673
# [003/010] Train Acc: 0.702278 Loss: 0.692889 | Val Acc: 0.700717 loss: 0.737438
# saving model with acc 0.701
# [004/010] Train Acc: 0.732970 Loss: 0.576458 | Val Acc: 0.724873 loss: 0.672948
# saving model with acc 0.725
# [005/010] Train Acc: 0.758468 Loss: 0.487055 | Val Acc: 0.736386 loss: 0.631933
# saving model with acc 0.736
# [006/010] Train Acc: 0.782131 Loss: 0.416472 | Val Acc: 0.753777 loss: 0.595505
# saving model with acc 0.754
# [007/010] Train Acc: 0.803552 Loss: 0.356559 | Val Acc: 0.756842 loss: 0.578435
# saving model with acc 0.757
# [008/010] Train Acc: 0.820013 Loss: 0.313453 | Val Acc: 0.774770 loss: 0.566269
# saving model with acc 0.775
# [009/010] Train Acc: 0.834819 Loss: 0.279790 | Val Acc: 0.775737 loss: 0.576419
# saving model with acc 0.776
# [010/010] Train Acc: 0.848356 Loss: 0.248773 | Val Acc: 0.787339 loss: 0.568857
# saving model with acc 0.787
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8483555537889205
# best_val_acc: 0.7873392197993399
# best_train_loss:0.24877317959682244
# best_val_loss:0.5688567491602307
# class 0 acc: 0.8000318928400574
# class 1 acc: 0.6176716417910447
# class 2 acc: 0.7426533523537803
# class 3 acc: 0.8053532102320854
# class 4 acc: 0.6786539943488312
# class 5 acc: 0.8756633813495072
# class 6 acc: 0.8044554455445545
# class 7 acc: 0.7522687254503589
# class 8 acc: 0.8663194444444444
# class 9 acc: 0.8778069407990667
# class 10 acc: 0.9338168631006346
# class 11 acc: 0.8983774551665243
# class 12 acc: 0.8805524449421426
# class 13 acc: 0.7970513706519236
# class 14 acc: 0.8148054573016675
# class 15 acc: 0.8880070546737213
# class 16 acc: 0.9020076481835564
# class 17 acc: 0.841645643314574
# class 18 acc: 0.859262229350441
# class 19 acc: 0.7866553336166596
# class 20 acc: 0.9165687426556992
# class 21 acc: 0.8319209039548022
# class 22 acc: 0.873758865248227
# class 23 acc: 0.798311444652908
# class 24 acc: 0.8067010309278351
# class 25 acc: 0.7798053527980535
# class 26 acc: 0.8978288633461047
# class 27 acc: 0.8712871287128713
# class 28 acc: 0.9007832898172323
# class 29 acc: 0.8391242265587815
# class 30 acc: 0.8752988047808765
# class 31 acc: 0.8004427577482606
# class 32 acc: 0.8041666666666667
# class 33 acc: 0.8913138367525099
# class 34 acc: 0.8511560693641619
# class 35 acc: 0.8128253667770942
# class 36 acc: 0.917312661498708
# class 37 acc: 0.8389830508474576
# class 38 acc: 0.67522802305411
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.586938 Loss: 1.156520 | Val Acc: 0.636226 loss: 0.973116
# saving model with acc 0.636
# [002/010] Train Acc: 0.665740 Loss: 0.838727 | Val Acc: 0.670545 loss: 0.825819
# saving model with acc 0.671
# [003/010] Train Acc: 0.703530 Loss: 0.689216 | Val Acc: 0.692757 loss: 0.737212
# saving model with acc 0.693
# [004/010] Train Acc: 0.734356 Loss: 0.574032 | Val Acc: 0.720970 loss: 0.668328
# saving model with acc 0.721
# [005/010] Train Acc: 0.760513 Loss: 0.484092 | Val Acc: 0.738426 loss: 0.624760
# saving model with acc 0.738
# [006/010] Train Acc: 0.783979 Loss: 0.412924 | Val Acc: 0.743581 loss: 0.598444
# saving model with acc 0.744
# [007/010] Train Acc: 0.804080 Loss: 0.356274 | Val Acc: 0.758996 loss: 0.589136
# saving model with acc 0.759
# [008/010] Train Acc: 0.820947 Loss: 0.313608 | Val Acc: 0.766346 loss: 0.567846
# saving model with acc 0.766
# [009/010] Train Acc: 0.836583 Loss: 0.276870 | Val Acc: 0.782290 loss: 0.564435
# saving model with acc 0.782
# [010/010] Train Acc: 0.849128 Loss: 0.248730 | Val Acc: 0.784128 loss: 0.545725
# saving model with acc 0.784
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8491279547725347
# best_val_acc: 0.7841276810250907
# best_train_loss:0.2487296808879757
# best_val_loss:0.5457253768916958
# class 0 acc: 0.7883910062191039
# class 1 acc: 0.5978507462686568
# class 2 acc: 0.755206847360913
# class 3 acc: 0.8117906149415551
# class 4 acc: 0.6714615977395325
# class 5 acc: 0.8703563305534496
# class 6 acc: 0.8341584158415841
# class 7 acc: 0.778816199376947
# class 8 acc: 0.8885416666666667
# class 9 acc: 0.8824730242053077
# class 10 acc: 0.9356300997280145
# class 11 acc: 0.9222886421861657
# class 12 acc: 0.8880179171332587
# class 13 acc: 0.7998157106657452
# class 14 acc: 0.8021728145528044
# class 15 acc: 0.8791887125220459
# class 16 acc: 0.8814531548757171
# ...
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.849178544778479
# best_val_acc: 0.788680748654406
# best_train_loss:0.24712716059536982
# best_val_loss:0.5666039329915007
# class 0 acc: 0.8094402806569925
# class 1 acc: 0.6002388059701492
# class 2 acc: 0.7380884450784594
# class 3 acc: 0.8143316957479247
# class 4 acc: 0.6966349858720781
# class 5 acc: 0.8623957543593631
# class 6 acc: 0.7995049504950495
# class 7 acc: 0.798049573344169
# class 8 acc: 0.8708333333333333
# class 9 acc: 0.8885972586759988
# class 10 acc: 0.9347234814143246
# class 11 acc: 0.9060631938514091
# class 12 acc: 0.8913773796192609
# class 13 acc: 0.7892190739460954
# class 14 acc: 0.8046993431025771
# class 15 acc: 0.8756613756613757
# class 16 acc: 0.872848948374761
# class 17 acc: 0.829225693770619
# class 18 acc: 0.8243785084202085
# class 19 acc: 0.8102422439439014
# class 20 acc: 0.881316098707403
# class 21 acc: 0.8983050847457628
# class 22 acc: 0.8425531914893617
# class 23 acc: 0.8095684803001876
# class 24 acc: 0.7551546391752577
# class 25 acc: 0.7931873479318735
# class 26 acc: 0.8837803320561941
# class 27 acc: 0.8696369636963697
# class 28 acc: 0.8929503916449086
# class 29 acc: 0.823417420276059
# class 30 acc: 0.8972111553784861
# class 31 acc: 0.8459835547122074
# class 32 acc: 0.8441666666666666
# class 33 acc: 0.8921868179834134
# class 34 acc: 0.8945086705202312
# class 35 acc: 0.8086843350686228
# class 36 acc: 0.9007013658176449
# class 37 acc: 0.8502824858757062
# class 38 acc: 0.6631973588495328
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.586781 Loss: 1.155893 | Val Acc: 0.639169 loss: 0.948575
# saving model with acc 0.639
# [002/010] Train Acc: 0.665605 Loss: 0.837406 | Val Acc: 0.679285 loss: 0.810229
# saving model with acc 0.679
# [003/010] Train Acc: 0.702786 Loss: 0.689205 | Val Acc: 0.698359 loss: 0.720321
# saving model with acc 0.698
# [004/010] Train Acc: 0.733925 Loss: 0.574759 | Val Acc: 0.725222 loss: 0.670040
# saving model with acc 0.725
# [005/010] Train Acc: 0.760013 Loss: 0.484938 | Val Acc: 0.733768 loss: 0.622245
# saving model with acc 0.734
# [006/010] Train Acc: 0.784280 Loss: 0.410147 | Val Acc: 0.751500 loss: 0.609227
# saving model with acc 0.752
# [007/010] Train Acc: 0.804000 Loss: 0.356566 | Val Acc: 0.768306 loss: 0.576068
# saving model with acc 0.768
# [008/010] Train Acc: 0.821871 Loss: 0.311557 | Val Acc: 0.773826 loss: 0.568531
# saving model with acc 0.774
# [009/010] Train Acc: 0.836627 Loss: 0.276372 | Val Acc: 0.779875 loss: 0.560124
# saving model with acc 0.780
# [010/010] Train Acc: 0.848698 Loss: 0.249281 | Val Acc: 0.784567 loss: 0.568696
# saving model with acc 0.785
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8486979397220079
# best_val_acc: 0.7845667268322032
# best_train_loss:0.24928074515494453
# best_val_loss:0.568695538300128
# class 0 acc: 0.8000318928400574
# class 1 acc: 0.5303880597014925
# class 2 acc: 0.7306704707560627
# class 3 acc: 0.8521090970692868
# class 4 acc: 0.7210377600821988
# class 5 acc: 0.8532979529946929
# class 6 acc: 0.8143564356435643
# class 7 acc: 0.7941216307733984
# class 8 acc: 0.8263888888888888
# class 9 acc: 0.8935549722951298
# class 10 acc: 0.9537624660018132
# class 11 acc: 0.8514090520922288
# class 12 acc: 0.8906308324001493
# class 13 acc: 0.8214697074406818
# class 14 acc: 0.8514401212733704
# class 15 acc: 0.8677248677248677
# class 16 acc: 0.8565965583173997
# class 17 acc: 0.8076848437803221
# class 18 acc: 0.8696872493985566
# class 19 acc: 0.7928176795580111
# class 20 acc: 0.9118683901292597
# class 21 acc: 0.8587570621468926
# class 22 acc: 0.8666666666666667
# class 23 acc: 0.7476547842401501
# class 24 acc: 0.788659793814433
# class 25 acc: 0.8309002433090025
# class 26 acc: 0.8582375478927203
# class 27 acc: 0.8894389438943895
# class 28 acc: 0.896431679721497
# class 29 acc: 0.7820085673488815
# class 30 acc: 0.8932270916334661
# class 31 acc: 0.8418722327640734
# class 32 acc: 0.8383333333333334
# class 33 acc: 0.890877346137058
# class 34 acc: 0.8583815028901735
# class 35 acc: 0.8018220539517275
# class 36 acc: 0.9509043927648578
# class 37 acc: 0.8693502824858758
# class 38 acc: 0.6574897879245706
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.587785 Loss: 1.154579 | Val Acc: 0.636332 loss: 0.959410
# saving model with acc 0.636
# [002/010] Train Acc: 0.665755 Loss: 0.838643 | Val Acc: 0.682082 loss: 0.830634
# saving model with acc 0.682
# [003/010] Train Acc: 0.702560 Loss: 0.689609 | Val Acc: 0.693920 loss: 0.741970
# saving model with acc 0.694
# [004/010] Train Acc: 0.732981 Loss: 0.576091 | Val Acc: 0.726255 loss: 0.676514
# saving model with acc 0.726
# [005/010] Train Acc: 0.759777 Loss: 0.486050 | Val Acc: 0.734938 loss: 0.634917
# saving model with acc 0.735
# [006/010] Train Acc: 0.783092 Loss: 0.414853 | Val Acc: 0.744736 loss: 0.605285
# saving model with acc 0.745
# [007/010] Train Acc: 0.803636 Loss: 0.357426 | Val Acc: 0.760411 loss: 0.575446
# saving model with acc 0.760
# [008/010] Train Acc: 0.821022 Loss: 0.313433 | Val Acc: 0.774371 loss: 0.572775
# saving model with acc 0.774
# [009/010] Train Acc: 0.835864 Loss: 0.278153 | Val Acc: 0.777973 loss: 0.556751
# saving model with acc 0.778
# [010/010] Train Acc: 0.848680 Loss: 0.249174 | Val Acc: 0.785672 loss: 0.575186
# saving model with acc 0.786
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8486798718627421
# best_val_acc: 0.785672471827894
# best_train_loss:0.24917433399166034
# best_val_loss:0.5751864984015788
# class 0 acc: 0.8043374262478074
# class 1 acc: 0.5650149253731344
# class 2 acc: 0.7203994293865906
# class 3 acc: 0.8285617482635947
# class 4 acc: 0.697148728487028
# class 5 acc: 0.8612585291887794
# class 6 acc: 0.8391089108910891
# class 7 acc: 0.778816199376947
# class 8 acc: 0.8739583333333333
# class 9 acc: 0.8958880139982502
# class 10 acc: 0.928377153218495
# class 11 acc: 0.9154568744662681
# class 12 acc: 0.8756998880179171
# class 13 acc: 0.7979728173231975
# class 14 acc: 0.8294593228903486
# class 15 acc: 0.8932980599647267
# class 16 acc: 0.8924474187380497
# class 17 acc: 0.7888608577527654
# class 18 acc: 0.8901363271852446
# class 19 acc: 0.779430514237144
# class 20 acc: 0.8777908343125734
# class 21 acc: 0.8305084745762712
# class 22 acc: 0.8439716312056738
# class 23 acc: 0.8058161350844277
# class 24 acc: 0.7448453608247423
# class 25 acc: 0.791970802919708
# class 26 acc: 0.8531289910600255
# class 27 acc: 0.8943894389438944
# class 28 acc: 0.8729329852045257
# class 29 acc: 0.8077106139933365
# class 30 acc: 0.8920318725099602
# class 31 acc: 0.816888045540797
# class 32 acc: 0.83
# class 33 acc: 0.8659973810563073
# class 34 acc: 0.8482658959537572
# class 35 acc: 0.8069096071935636
# class 36 acc: 0.9413067552602437
# class 37 acc: 0.902542372881356
# class 38 acc: 0.6758995019864585
# DEVICE: cuda
# Loading data ...
# Size of training data: (1229932, 429)
# Size of training set: (1106938, 429)
# Size of validation set: (122994, 429)
# Creating data loader...
# [001/010] Train Acc: 0.587131 Loss: 1.155947 | Val Acc: 0.635023 loss: 0.976959
# saving model with acc 0.635
# [002/010] Train Acc: 0.666270 Loss: 0.836915 | Val Acc: 0.678521 loss: 0.827838
# saving model with acc 0.679
# [003/010] Train Acc: 0.703274 Loss: 0.688866 | Val Acc: 0.696473 loss: 0.737475
# saving model with acc 0.696
# [004/010] Train Acc: 0.734183 Loss: 0.575030 | Val Acc: 0.719856 loss: 0.676238
# saving model with acc 0.720
# [005/010] Train Acc: 0.760511 Loss: 0.484808 | Val Acc: 0.738548 loss: 0.635783
# saving model with acc 0.739
# [006/010] Train Acc: 0.783809 Loss: 0.413171 | Val Acc: 0.746638 loss: 0.609305
# saving model with acc 0.747
# [007/010] Train Acc: 0.803996 Loss: 0.357434 | Val Acc: 0.759793 loss: 0.584117
# saving model with acc 0.760
# [008/010] Train Acc: 0.821656 Loss: 0.312890 | Val Acc: 0.770013 loss: 0.587719
# saving model with acc 0.770
# [009/010] Train Acc: 0.837081 Loss: 0.274259 | Val Acc: 0.779973 loss: 0.559504
# saving model with acc 0.780
# [010/010] Train Acc: 0.849066 Loss: 0.250251 | Val Acc: 0.790518 loss: 0.575929
# saving model with acc 0.791
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [-1, 2048]         880,640
#               ReLU-2                 [-1, 2048]               0
#        BatchNorm1d-3                 [-1, 2048]           4,096
#             Linear-4                 [-1, 1024]       2,098,176
#               ReLU-5                 [-1, 1024]               0
#        BatchNorm1d-6                 [-1, 1024]           2,048
#             Linear-7                  [-1, 512]         524,800
#               ReLU-8                  [-1, 512]               0
#        BatchNorm1d-9                  [-1, 512]           1,024
#            Linear-10                  [-1, 256]         131,328
#              ReLU-11                  [-1, 256]               0
#       BatchNorm1d-12                  [-1, 256]             512
#            Linear-13                   [-1, 39]          10,023
# ================================================================
# Total params: 3,652,647
# Trainable params: 3,652,647
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.09
# Params size (MB): 13.93
# Estimated Total Size (MB): 14.02
# ----------------------------------------------------------------
# best_train_acc: 0.8490656206580676
# best_val_acc: 0.790518236661951
# best_train_loss:0.250250926883986
# best_val_loss:0.5759290205545662
# class 0 acc: 0.8088024238558443
# class 1 acc: 0.5986865671641791
# class 2 acc: 0.7092724679029957
# class 3 acc: 0.8466881246823649
# class 4 acc: 0.7045979964038017
# class 5 acc: 0.8642911296436695
# class 6 acc: 0.8366336633663366
# class 7 acc: 0.789245564133821
# class 8 acc: 0.8819444444444444
# class 9 acc: 0.8850976961213182
# class 10 acc: 0.9492293744333635
# class 11 acc: 0.8958155422715628
# class 12 acc: 0.8312803284807764
# class 13 acc: 0.7873761806035475
# class 14 acc: 0.8292066700353714
# class 15 acc: 0.8395061728395061
# class 16 acc: 0.8580305927342257
# class 17 acc: 0.8197166699010285
# class 18 acc: 0.8757016840417001
# class 19 acc: 0.8113047173820654
# class 20 acc: 0.8519388954171563
# class 21 acc: 0.9110169491525424
# class 22 acc: 0.8567375886524823
# class 23 acc: 0.7157598499061913
# class 24 acc: 0.8427835051546392
# class 25 acc: 0.791970802919708
# class 26 acc: 0.8620689655172413
# class 27 acc: 0.8646864686468647
# class 28 acc: 0.8546562228024369
# class 29 acc: 0.8296049500237982
# class 30 acc: 0.9099601593625498
# class 31 acc: 0.8434535104364327
# class 32 acc: 0.83
# class 33 acc: 0.8716717590571803
# class 34 acc: 0.7528901734104047
# class 35 acc: 0.8213440605773782
# class 36 acc: 0.9091915836101883
# class 37 acc: 0.8806497175141242
# class 38 acc: 0.6795366795366795
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Loading data ...
# Size of testing data: (451552, 429)
# Predicting...
# Saving...
# Finishing...
# config: {'BATCH_SIZE': 1024, 'INPUT_DIM': 429, 'OUTPUT_DIM': 39, 'NUM_EPOCH': 10, 'MODEL_PATH': './model.ckpt', 'MOMENTUM': 0.01, 'EARLY_STOP': 10, 'DROPOUT_PROB': 0.5, 'INPUT_DROPOUT_PROB': 0.2, 'TEST_SIZE': 0.1, 'WIGHT_DECAY': 0, 'MODEL_NUM': 20, 'RANDOM_STATE': 20}
